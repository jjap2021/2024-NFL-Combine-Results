# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
# %run Scraping_2024_PFR.ipynb
# %run scraping_past_years.ipynb
# Out:
#                  player pos school_name        college height weight forty_yd  \
# 1    Kris Abrams-Draine  CB    Missouri  College Stats   5-11    179     4.44
# 2          Isaiah Adams   G    Illinois  College Stats    6-4    315     5.22
# 3           Rasheen Ali  RB    Marshall  College Stats   5-11    206
# 4             Erick All  TE        Iowa  College Stats    6-4    252
# 5         Braelon Allen  RB   Wisconsin  College Stats    6-1    235
# ..                  ...  ..         ...            ...    ...    ...      ...
# 323        Roman Wilson  WR    Michigan  College Stats   5-11    185     4.39
# 324         Mekhi Wingo  DT         LSU  College Stats    6-0    284     4.85
# 325       Xavier Worthy  WR       Texas  College Stats   5-11    165     4.21
# 326       Jaylen Wright  RB   Tennessee  College Stats   5-11    210     4.38
# 327          Zak Zinter   G    Michigan  College Stats    6-6    309
#
#     vertical bench_reps broad_jump  cone shuttle draft_info
# ...
